# %% [markdown]
# # 📊 Bài tập thực hành: Trực quan hóa dữ liệu
#
# ## 🎯 Mục tiêu bài tập
#
# Sau khi hoàn thành các bài tập này, bạn sẽ có thể:
#
# ✅ **Tạo các biểu đồ cơ bản với matplotlib** (line plot, bar chart, histogram)
# ✅ **Sử dụng seaborn** để tạo các biểu đồ thống kê nâng cao
# ✅ **Áp dụng pandas plotting** để trực quan hóa dữ liệu nhanh chóng
# ✅ **Chọn loại biểu đồ phù hợp** cho từng tình huống phân tích
# ✅ **Áp dụng các nguyên tắc thiết kế tốt** để tạo biểu đồ rõ ràng và hiệu quả
# ✅ **Nhận biết và sửa các lỗi thiết kế** trong trực quan hóa dữ liệu
#
# ---
#
# ## 📋 Cấu trúc bài tập
#
# **Phần 1: Matplotlib cơ bản** (~15 phút)
# - Bài 1.1: Biểu đồ đường (Line plot) - Doanh thu theo thời gian
# - Bài 1.2: Biểu đồ cột (Bar chart) - Doanh số theo danh mục sản phẩm
#
# **Phần 2: Trực quan hóa thống kê** (~15 phút)
# - Bài 2.1: Histogram và Density plot - Phân bố lương nhân viên
# - Bài 2.2: Boxplot - So sánh doanh số theo khu vực
#
# **Phần 3: Seaborn nâng cao** (~15 phút)
# - Bài 3.1: Seaborn histogram với KDE
# - Bài 3.2: Scatter plot với đường hồi quy
#
# **Phần 4: Pandas Plotting** (~10 phút)
# - Bài 4.1: Trực quan hóa nhanh với pandas
#
# **Phần 5: Seaborn nâng cao (tiếp theo)** (~20 phút)
# - Bài 5.1: Heatmap (Bản đồ nhiệt)
# - Bài 5.2: Violin Plot
# - Bài 5.3: Pair Plot (Biểu đồ cặp)
#
# **Phần 6: Trực quan hóa nâng cao** (~25 phút)
# - Bài 6.1: Subplots với nhiều biểu đồ
# - Bài 6.2: Biểu đồ theo nhóm (Grouped Visualization)
# - Bài 6.3: Time Series Visualization
# - Bài 6.4: Customization và Styling nâng cao
#
# ---
#
# ## ⚠️ Lưu ý quan trọng
#
# > **💡 Cho sinh viên Kinh tế:** Các bài tập này được thiết kế dựa trên các tình huống thực tế trong kinh doanh và nghiên cứu kinh tế.
#
# > **🔧 Tương thích:** Notebook này hoạt động tốt trên cả **Jupyter Notebook**, **JupyterLab**, và **Google Colab**.
#
# > **📚 Tham khảo:** Hãy xem lại **Lecture 7** trước khi làm bài tập để hiểu rõ lý thuyết.
#
# > **⏱️ Thời gian:** Tổng thời gian dự kiến cho tất cả bài tập là khoảng **100 phút**.

# %% [markdown]
# ## 🛠️ Thiết lập môi trường
#
# Trước khi bắt đầu làm bài tập, hãy đảm bảo bạn đã cài đặt các thư viện cần thiết:
#
# **📦 Cài đặt thư viện (chạy cell này nếu bạn đang sử dụng Google Colab):**

# %%
# Cài đặt thư viện cho Google Colab (bỏ qua nếu đã cài đặt)
try:
    import pandas as pd
    import numpy as np
    import matplotlib.pyplot as plt
    import seaborn as sns
    from scipy import stats
    from scipy.stats import pearsonr
    print("✅ Tất cả thư viện đã sẵn sàng!")
    print("🚀 Bạn có thể bắt đầu làm bài tập!")
except ImportError as e:
    print(f"❌ Thiếu thư viện: {e}")
    print("🔧 Đang cài đặt...")
    import subprocess
    import sys
    
    # Cài đặt các thư viện cần thiết
    packages = ['pandas', 'numpy', 'matplotlib', 'seaborn', 'scipy']
    for package in packages:
        subprocess.check_call([sys.executable, '-m', 'pip', 'install', package])
    
    print("✅ Cài đặt hoàn tất! Vui lòng restart kernel và chạy lại cell này.")

# Thiết lập matplotlib để hiển thị trong notebook
try:
    get_ipython().run_line_magic('matplotlib', 'inline')
except:
    pass

# Thiết lập style cho seaborn
sns.set_theme(style="whitegrid", palette="deep")
plt.style.use('seaborn-v0_8')
# Out:
# ✅ Tất cả thư viện đã sẵn sàng!
# 🚀 Bạn có thể bắt đầu làm bài tập!

# %% [markdown]
# ## 📊 Tạo dữ liệu ban đầu
#
# Chúng ta sẽ tạo các bộ dữ liệu mẫu để sử dụng trong các bài tập. Chạy cell này để tạo tất cả dữ liệu cần thiết.

# %%
# 📊 TẠO DỮ LIỆU BAN ĐẦU
# Chạy cell này để tạo tất cả dữ liệu mẫu cho các bài tập

import pandas as pd
import numpy as np

# Thiết lập seed để kết quả có thể tái tạo
np.random.seed(42)

print("📊 Đang tạo dữ liệu mẫu...")

# 1. Dữ liệu doanh thu theo tháng (cho Bài 1.1)
months = np.arange(1, 13)
base_revenue = 100
trend = np.linspace(0, 50, 12)
noise = np.random.normal(0, 10, 12)
revenue_data = base_revenue + trend + noise
revenue_data = np.maximum(revenue_data, 80)

print("✅ Dữ liệu doanh thu theo tháng đã tạo")

# 2. Dữ liệu doanh số theo danh mục (cho Bài 1.2)
categories = ['Điện tử', 'Thời trang', 'Thực phẩm', 'Sách', 'Thể thao']
sales_data = np.array([150, 120, 200, 80, 100])

print("✅ Dữ liệu doanh số theo danh mục đã tạo")

# 3. Dữ liệu lương nhân viên (cho Bài 2.1)
salary_data = np.random.normal(loc=15, scale=5, size=100)
salary_data = np.clip(salary_data, 5, 30)

print("✅ Dữ liệu lương nhân viên đã tạo")

# 4. Dữ liệu doanh số theo khu vực (cho Bài 2.2)
bac = np.random.normal(loc=150, scale=20, size=50)
trung = np.random.normal(loc=120, scale=15, size=50)
nam = np.random.normal(loc=180, scale=25, size=50)
tay_nguyen = np.random.normal(loc=100, scale=18, size=50)
region_data = {
    'Bắc': bac,
    'Trung': trung,
    'Nam': nam,
    'Tây Nguyên': tay_nguyen
}

print("✅ Dữ liệu doanh số theo khu vực đã tạo")

# 5. Dữ liệu điểm số học sinh (cho Bài 3.1)
scores_data = np.random.normal(loc=7, scale=1.5, size=200)
scores_data = np.clip(scores_data, 0, 10)
df_scores = pd.DataFrame({'Diem': scores_data})

print("✅ Dữ liệu điểm số học sinh đã tạo")

# 6. Dữ liệu học tập (cho Bài 3.2)
study_hours_data = np.random.uniform(10, 40, 100)
scores_study = 5 + 0.15 * study_hours_data + np.random.normal(0, 1, 100)
scores_study = np.clip(scores_study, 0, 10)
df_study = pd.DataFrame({
    'GioHoc': study_hours_data,
    'Diem': scores_study
})

print("✅ Dữ liệu học tập đã tạo")

# 7. Dữ liệu doanh thu theo tháng và sản phẩm (cho Bài 4.1)
months_dates = pd.date_range('2024-01-01', periods=12, freq='M')
revenue_products = {
    'SanPham_A': np.random.randint(100, 200, 12).cumsum(),
    'SanPham_B': np.random.randint(80, 180, 12).cumsum(),
    'SanPham_C': np.random.randint(120, 220, 12).cumsum()
}
df_revenue = pd.DataFrame(revenue_products, index=months_dates)

print("✅ Dữ liệu doanh thu theo sản phẩm đã tạo")

# 8. Dữ liệu bổ sung cho các bài tập mới
# Dữ liệu bán hàng theo tháng và nhân viên
sales_employees = pd.DataFrame({
    'Thang': pd.date_range('2024-01-01', periods=6, freq='M'),
    'NV_A': np.random.randint(50, 100, 6),
    'NV_B': np.random.randint(60, 110, 6),
    'NV_C': np.random.randint(45, 95, 6),
    'NV_D': np.random.randint(55, 105, 6)
})

# Dữ liệu khách hàng với nhiều thuộc tính
customer_data = pd.DataFrame({
    'Tuoi': np.random.randint(18, 65, 150),
    'ThuNhap': np.random.randint(10, 50, 150) * 1000000,
    'ChiTieu': np.random.randint(5, 30, 150) * 1000000,
    'GioiTinh': np.random.choice(['Nam', 'Nữ'], 150),
    'ThanhPho': np.random.choice(['Hà Nội', 'TP.HCM', 'Đà Nẵng', 'Cần Thơ'], 150)
})

print("✅ Dữ liệu bổ sung đã tạo")

print("\n🎉 Tất cả dữ liệu đã sẵn sàng!")
print("📝 Bạn có thể sử dụng các biến sau trong các bài tập:")
print("   - months, revenue_data (Bài 1.1)")
print("   - categories, sales_data (Bài 1.2)")
print("   - salary_data (Bài 2.1)")
print("   - region_data (Bài 2.2)")
print("   - df_scores (Bài 3.1)")
print("   - df_study (Bài 3.2)")
print("   - df_revenue (Bài 4.1)")
print("   - sales_employees, customer_data (Các bài tập mới)")
# Out:
# 📊 Đang tạo dữ liệu mẫu...
# ✅ Dữ liệu doanh thu theo tháng đã tạo
# ✅ Dữ liệu doanh số theo danh mục đã tạo
# ✅ Dữ liệu lương nhân viên đã tạo
# ✅ Dữ liệu doanh số theo khu vực đã tạo
# ✅ Dữ liệu điểm số học sinh đã tạo
# ✅ Dữ liệu học tập đã tạo
# ✅ Dữ liệu doanh thu theo sản phẩm đã tạo
# ✅ Dữ liệu bổ sung đã tạo
#
# 🎉 Tất cả dữ liệu đã sẵn sàng!
# 📝 Bạn có thể sử dụng các biến sau trong các bài tập:
#    - months, revenue_data (Bài 1.1)
#    - categories, sales_data (Bài 1.2)
#    - salary_data (Bài 2.1)
#    - region_data (Bài 2.2)
#    - df_scores (Bài 3.1)
#    - df_study (Bài 3.2)
#    - df_revenue (Bài 4.1)
#    - sales_employees, customer_data (Các bài tập mới)
# /var/folders/8x/cphm0p8j0h16x_zm6w8f2nww0000gn/T/ipykernel_7997/3359396384.py:67: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   months_dates = pd.date_range('2024-01-01', periods=12, freq='M')
# ...

# %% [markdown]
# # 📈 Phần 1: Matplotlib cơ bản
#
# ## Bài 1.1 - Biểu đồ đường (Line Plot)
#
# ### 📊 Tình huống thực tế
# Bạn là nhân viên phân tích dữ liệu tại một công ty bán lẻ. Bạn cần tạo biểu đồ đường để hiển thị xu hướng doanh thu theo tháng trong năm 2024 để trình bày cho ban giám đốc.
#
# ### 🎯 Nhiệm vụ của bạn:
# 1. **Tạo dữ liệu mẫu** về doanh thu theo tháng
# 2. **Vẽ biểu đồ đường** với matplotlib
# 3. **Thêm nhãn và tiêu đề** cho biểu đồ
# 4. **Tùy chỉnh màu sắc và style** của đường
#
# ### 📋 Yêu cầu cụ thể:
# - Sử dụng `matplotlib.pyplot` để vẽ biểu đồ
# - Tạo dữ liệu doanh thu cho 12 tháng (từ tháng 1 đến tháng 12)
# - Thêm tiêu đề: "Doanh thu theo tháng năm 2024"
# - Thêm nhãn cho trục x: "Tháng" và trục y: "Doanh thu (triệu VND)"
# - Sử dụng màu xanh dương và marker 'o' cho các điểm dữ liệu

# %%
# 📊 BÀI TẬP 1.1: Biểu đồ đường (Line Plot)
# Hãy hoàn thành các yêu cầu dưới đây:
# Lưu ý: Sử dụng dữ liệu đã tạo sẵn (months, revenue_data) từ cell "Tạo dữ liệu ban đầu"

import matplotlib.pyplot as plt
import numpy as np

# 1. Sử dụng dữ liệu đã tạo sẵn
print("📊 Sử dụng dữ liệu doanh thu đã tạo...")
print(f"Dữ liệu: {len(months)} tháng, doanh thu từ {revenue_data.min():.0f} đến {revenue_data.max():.0f} triệu VND")

# 2. Vẽ biểu đồ đường
print("\n📈 Vẽ biểu đồ đường...")

# TODO: Sử dụng plt.plot() để vẽ biểu đồ với months và revenue_data
# TODO: Thêm tiêu đề "Doanh thu theo tháng năm 2024"
# TODO: Thêm nhãn cho trục x ("Tháng") và trục y ("Doanh thu (triệu VND)")
# TODO: Hiển thị lưới (grid)
# TODO: (Tùy chọn) Thêm nhãn giá trị trên các điểm dữ liệu
# TODO: Hiển thị biểu đồ với plt.show()

print("\n✅ Hoàn thành Bài tập 1.1!")
# Out:
# 📊 Sử dụng dữ liệu doanh thu đã tạo...
# Dữ liệu: 12 tháng, doanh thu từ 103 đến 146 triệu VND
#
# 📈 Vẽ biểu đồ đường...
#
# ✅ Hoàn thành Bài tập 1.1!

# %% [markdown]
# ## Bài 1.2 - Biểu đồ cột (Bar Chart)
#
# ### 📊 Tình huống thực tế
# Bạn cần so sánh doanh số bán hàng của 5 danh mục sản phẩm khác nhau trong quý 1. Biểu đồ cột sẽ giúp dễ dàng so sánh giá trị giữa các danh mục.
#
# ### 🎯 Nhiệm vụ của bạn:
# 1. **Tạo dữ liệu** về doanh số theo danh mục sản phẩm
# 2. **Vẽ biểu đồ cột** với matplotlib
# 3. **Tùy chỉnh màu sắc** cho từng cột
# 4. **Thêm nhãn giá trị** trên đầu mỗi cột
#
# ### 📋 Yêu cầu cụ thể:
# - Tạo dữ liệu cho 5 danh mục: "Điện tử", "Thời trang", "Thực phẩm", "Sách", "Thể thao"
# - Sử dụng `plt.bar()` để vẽ biểu đồ cột
# - Màu sắc khác nhau cho mỗi cột
# - Thêm nhãn giá trị trên đầu mỗi cột bằng `plt.text()` hoặc vòng lặp

# %%
# 📊 BÀI TẬP 1.2: Biểu đồ cột (Bar Chart)
# Hãy hoàn thành các yêu cầu dưới đây:
# Lưu ý: Sử dụng dữ liệu đã tạo sẵn (categories, sales_data) từ cell "Tạo dữ liệu ban đầu"

import matplotlib.pyplot as plt
import numpy as np

# 1. Sử dụng dữ liệu đã tạo sẵn
print("📊 Sử dụng dữ liệu doanh số theo danh mục...")
print(f"Danh mục: {categories}")
print(f"Doanh số: {sales_data}")

# 2. Vẽ biểu đồ cột
print("\n📊 Vẽ biểu đồ cột...")

# TODO: Tạo figure và axes với kích thước phù hợp
# TODO: Vẽ biểu đồ cột với màu sắc khác nhau cho mỗi danh mục
# TODO: Thêm tiêu đề và nhãn cho trục x, y
# TODO: Thêm nhãn giá trị trên đầu mỗi cột (sử dụng vòng lặp)
# TODO: Thêm grid
# TODO: Hiển thị biểu đồ

print("\n✅ Hoàn thành Bài tập 1.2!")
# Out:
# 📊 Sử dụng dữ liệu doanh số theo danh mục...
# Danh mục: ['Điện tử', 'Thời trang', 'Thực phẩm', 'Sách', 'Thể thao']
# Doanh số: [150 120 200  80 100]
#
# 📊 Vẽ biểu đồ cột...
#
# ✅ Hoàn thành Bài tập 1.2!

# %% [markdown]
# # 📊 Phần 2: Trực quan hóa thống kê
#
# ## Bài 2.1 - Histogram và Density Plot
#
# ### 📊 Tình huống thực tế
# Bộ phận HR cung cấp dữ liệu về mức lương của nhân viên. Bạn cần phân tích phân bố lương để hiểu cấu trúc lương trong công ty.
#
# ### 🎯 Nhiệm vụ của bạn:
# 1. **Tạo dữ liệu mẫu** về lương nhân viên
# 2. **Vẽ histogram** để hiển thị phân bố lương
# 3. **Thêm density plot** (KDE) để làm mượt phân bố
# 4. **So sánh** histogram và density plot
#
# ### 📋 Yêu cầu cụ thể:
# - Tạo dữ liệu lương cho 100 nhân viên (triệu VND/tháng)
# - Sử dụng `plt.hist()` để vẽ histogram với 20 bins
# - Sử dụng `scipy.stats` hoặc `seaborn` để thêm density plot
# - Thêm tiêu đề và nhãn phù hợp

# %%
# 📊 BÀI TẬP 2.1: Histogram và Density Plot
# Hãy hoàn thành các yêu cầu dưới đây:
# Lưu ý: Sử dụng dữ liệu đã tạo sẵn (salary_data) từ cell "Tạo dữ liệu ban đầu"

import matplotlib.pyplot as plt
import numpy as np
from scipy import stats

# 1. Sử dụng dữ liệu đã tạo sẵn
print("💰 Sử dụng dữ liệu lương nhân viên...")
print(f"Số lượng nhân viên: {len(salary_data)}")
print(f"Lương trung bình: {np.mean(salary_data):.2f} triệu VND")

# 2. Vẽ histogram
print("\n📊 Vẽ histogram...")

# TODO: Tạo figure với 2 subplot (histogram và density plot)
# TODO: Vẽ histogram trên subplot đầu tiên với salary_data (20 bins)
# TODO: Vẽ histogram với density plot overlay trên subplot thứ hai
# TODO: Thêm density plot (KDE) sử dụng scipy.stats.gaussian_kde
# TODO: Thêm tiêu đề và nhãn cho cả hai subplot
# TODO: Hiển thị biểu đồ
# TODO: In thống kê mô tả (trung bình, trung vị, độ lệch chuẩn, min, max)

print("\n✅ Hoàn thành Bài tập 2.1!")
# Out:
# 💰 Sử dụng dữ liệu lương nhân viên...
# Số lượng nhân viên: 100
# Lương trung bình: 14.21 triệu VND
#
# 📊 Vẽ histogram...
#
# ✅ Hoàn thành Bài tập 2.1!

# %% [markdown]
# ## Bài 2.2 - Boxplot So sánh
#
# ### 📊 Tình huống thực tế
# Bạn cần so sánh doanh số bán hàng giữa 4 khu vực khác nhau (Bắc, Trung, Nam, Tây Nguyên) để xác định khu vực nào có hiệu suất tốt nhất.
#
# ### 🎯 Nhiệm vụ của bạn:
# 1. **Tạo dữ liệu** doanh số cho 4 khu vực
# 2. **Vẽ boxplot** để so sánh phân bố doanh số
# 3. **Thêm thông tin thống kê** (median, quartiles)
# 4. **Nhận xét** về sự khác biệt giữa các khu vực
#
# ### 📋 Yêu cầu cụ thể:
# - Tạo dữ liệu doanh số cho mỗi khu vực (mỗi khu vực có 50 điểm dữ liệu)
# - Sử dụng `plt.boxplot()` để vẽ boxplot
# - Thêm nhãn cho các khu vực
# - Tùy chỉnh màu sắc và style

# %%
# 📊 BÀI TẬP 2.2: Boxplot So sánh
# Hãy hoàn thành các yêu cầu dưới đây:
# Lưu ý: Sử dụng dữ liệu đã tạo sẵn (region_data) từ cell "Tạo dữ liệu ban đầu"

import matplotlib.pyplot as plt
import numpy as np

# 1. Sử dụng dữ liệu đã tạo sẵn
print("📊 Sử dụng dữ liệu doanh số theo khu vực...")
print(f"Khu vực: {list(region_data.keys())}")
for region, data in region_data.items():
    print(f"  {region}: {len(data)} điểm dữ liệu, trung bình = {np.mean(data):.2f}")

# TODO: Tổ chức dữ liệu thành list để vẽ boxplot

# 2. Vẽ boxplot
print("\n📦 Vẽ boxplot...")

# TODO: Tạo figure
# TODO: Vẽ boxplot với patch_artist=True, showmeans=True
# TODO: Tùy chỉnh màu sắc cho từng box
# TODO: Thêm tiêu đề và nhãn
# TODO: Hiển thị biểu đồ
# TODO: In thống kê cho mỗi khu vực (trung bình, trung vị, Q1, Q3)

print("\n✅ Hoàn thành Bài tập 2.2!")
# Out:
# 📊 Sử dụng dữ liệu doanh số theo khu vực...
# Khu vực: ['Bắc', 'Trung', 'Nam', 'Tây Nguyên']
#   Bắc: 50 điểm dữ liệu, trung bình = 150.73
#   Trung: 50 điểm dữ liệu, trung bình = 123.21
#   Nam: 50 điểm dữ liệu, trung bình = 180.65
#   Tây Nguyên: 50 điểm dữ liệu, trung bình = 99.75
#
# 📦 Vẽ boxplot...
#
# ✅ Hoàn thành Bài tập 2.2!

# %% [markdown]
# # 🎨 Phần 3: Seaborn nâng cao
#
# ## Bài 3.1 - Seaborn Histogram với KDE
#
# ### 📊 Tình huống thực tế
# Bạn cần phân tích phân bố điểm số của học sinh trong một kỳ thi. Seaborn cung cấp các công cụ trực quan hóa thống kê mạnh mẽ và đẹp mắt hơn matplotlib.
#
# ### 🎯 Nhiệm vụ của bạn:
# 1. **Tạo dữ liệu** điểm số học sinh
# 2. **Sử dụng seaborn** để vẽ histogram với KDE
# 3. **So sánh** với matplotlib histogram
#
# ### 📋 Yêu cầu cụ thể:
# - Tạo dữ liệu điểm số cho 200 học sinh (thang điểm 0-10)
# - Sử dụng `sns.histplot()` với `kde=True`
# - Tùy chỉnh màu sắc và style theo seaborn theme

# %%
# 📊 BÀI TẬP 3.1: Seaborn Histogram với KDE
# Hãy hoàn thành các yêu cầu dưới đây:
# Lưu ý: Sử dụng dữ liệu đã tạo sẵn (df_scores) từ cell "Tạo dữ liệu ban đầu"

import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# 1. Sử dụng dữ liệu đã tạo sẵn
print("📊 Sử dụng dữ liệu điểm số học sinh...")
print(f"Số lượng học sinh: {len(df_scores)}")
print(f"Điểm trung bình: {df_scores['Diem'].mean():.2f}")

# 2. Vẽ histogram với seaborn
print("\n📊 Vẽ histogram với seaborn...")

# TODO: Tạo figure
# TODO: Sử dụng sns.histplot() với kde=True trên df_scores
# TODO: Thêm tiêu đề và nhãn
# TODO: Thêm grid
# TODO: Hiển thị biểu đồ

print("\n✅ Hoàn thành Bài tập 3.1!")
# Out:
# 📊 Sử dụng dữ liệu điểm số học sinh...
# Số lượng học sinh: 200
# Điểm trung bình: 7.00
#
# 📊 Vẽ histogram với seaborn...
#
# ✅ Hoàn thành Bài tập 3.1!

# %% [markdown]
# ## Bài 3.2 - Scatter Plot với Đường Hồi quy
#
# ### 📊 Tình huống thực tế
# Bạn cần phân tích mối quan hệ giữa số giờ học và điểm số của học sinh. Scatter plot với đường hồi quy sẽ giúp bạn nhận thấy xu hướng và mối tương quan.
#
# ### 🎯 Nhiệm vụ của bạn:
# 1. **Tạo dữ liệu** về số giờ học và điểm số
# 2. **Vẽ scatter plot** với seaborn
# 3. **Thêm đường hồi quy** (regression line)
# 4. **Tính hệ số tương quan** và nhận xét
#
# ### 📋 Yêu cầu cụ thể:
# - Tạo dữ liệu cho 100 học sinh (số giờ học và điểm số tương ứng)
# - Sử dụng `sns.scatterplot()` và `sns.regplot()` hoặc `sns.lmplot()`
# - Thêm nhãn và tiêu đề phù hợp

# %%
# 📊 BÀI TẬP 3.2: Scatter Plot với Đường Hồi quy
# Hãy hoàn thành các yêu cầu dưới đây:
# Lưu ý: Sử dụng dữ liệu đã tạo sẵn (df_study) từ cell "Tạo dữ liệu ban đầu"

import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy.stats import pearsonr

# 1. Sử dụng dữ liệu đã tạo sẵn
print("📊 Sử dụng dữ liệu học tập...")
print(f"Số lượng học sinh: {len(df_study)}")
print(f"Số giờ học trung bình: {df_study['GioHoc'].mean():.2f} giờ/tuần")
print(f"Điểm trung bình: {df_study['Diem'].mean():.2f}")

# 2. Vẽ scatter plot với đường hồi quy
print("\n📊 Vẽ scatter plot với regression line...")

# TODO: Tạo figure
# TODO: Sử dụng sns.regplot() để vẽ scatter plot + regression line trên df_study
# TODO: Thêm tiêu đề và nhãn
# TODO: Thêm grid
# TODO: Hiển thị biểu đồ
# TODO: Tính hệ số tương quan Pearson và in nhận xét

print("\n✅ Hoàn thành Bài tập 3.2!")
# Out:
# 📊 Sử dụng dữ liệu học tập...
# Số lượng học sinh: 100
# Số giờ học trung bình: 25.12 giờ/tuần
# Điểm trung bình: 8.57
#
# 📊 Vẽ scatter plot với regression line...
#
# ✅ Hoàn thành Bài tập 3.2!

# %% [markdown]
# # 🐼 Phần 4: Pandas Plotting
#
# ## Bài 4.1 - Trực quan hóa nhanh với Pandas
#
# ### 📊 Tình huống thực tế
# Bạn có một DataFrame chứa dữ liệu doanh thu theo tháng và sản phẩm. Pandas cung cấp các phương thức `.plot()` tiện lợi để trực quan hóa nhanh chóng mà không cần import matplotlib riêng.
#
# ### 🎯 Nhiệm vụ của bạn:
# 1. **Tạo DataFrame** với dữ liệu doanh thu
# 2. **Sử dụng pandas `.plot()`** để vẽ các loại biểu đồ khác nhau
# 3. **So sánh** các phương pháp vẽ của pandas
#
# ### 📋 Yêu cầu cụ thể:
# - Tạo DataFrame với dữ liệu doanh thu theo tháng cho 3 sản phẩm
# - Sử dụng `.plot()` với các tham số `kind='line'`, `kind='bar'`, `kind='area'`
# - Tùy chỉnh tiêu đề và nhãn

# %%
# 📊 BÀI TẬP 4.1: Trực quan hóa nhanh với Pandas
# Hãy hoàn thành các yêu cầu dưới đây:
# Lưu ý: Sử dụng dữ liệu đã tạo sẵn (df_revenue) từ cell "Tạo dữ liệu ban đầu"

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# 1. Sử dụng dữ liệu đã tạo sẵn
print("📊 Sử dụng DataFrame doanh thu...")
print(f"DataFrame shape: {df_revenue.shape}")
print(df_revenue.head())

# 2. Vẽ biểu đồ với pandas
print("\n📊 Vẽ biểu đồ với pandas...")

# TODO: Vẽ line plot với df_revenue.plot(kind='line')
# TODO: Vẽ bar chart với df_revenue.plot(kind='bar')
# TODO: Vẽ area chart (stacked) với df_revenue.plot(kind='area')
# TODO: Thêm tiêu đề, nhãn và legend cho mỗi biểu đồ
# TODO: Hiển thị các biểu đồ

print("\n✅ Hoàn thành Bài tập 4.1!")
# Out:
# 📊 Sử dụng DataFrame doanh thu...
# DataFrame shape: (12, 3)
#             SanPham_A  SanPham_B  SanPham_C
# 2024-01-31        146        173        206
# 2024-02-29        314        261        421
# 2024-03-31        433        438        621
# 2024-04-30        543        570        821
# 2024-05-31        644        693        954
#
# 📊 Vẽ biểu đồ với pandas...
#
# ✅ Hoàn thành Bài tập 4.1!

# %% [markdown]
# # 🎨 Phần 5: Seaborn nâng cao (tiếp theo)
#
# ## Bài 5.1 - Heatmap (Bản đồ nhiệt)
#
# ### 📊 Tình huống thực tế
# Bạn cần phân tích ma trận tương quan giữa các biến trong dữ liệu khách hàng để hiểu mối quan hệ giữa tuổi, thu nhập, và chi tiêu. Heatmap là công cụ tuyệt vời để trực quan hóa ma trận dữ liệu.
#
# ### 🎯 Nhiệm vụ của bạn:
# 1. **Tính ma trận tương quan** từ dữ liệu khách hàng
# 2. **Vẽ heatmap** với seaborn
# 3. **Tùy chỉnh màu sắc và annotations**
#
# ### 📋 Yêu cầu cụ thể:
# - Sử dụng dữ liệu `customer_data` đã tạo sẵn
# - Tính ma trận tương quan cho các cột số (Tuoi, ThuNhap, ChiTieu)
# - Sử dụng `sns.heatmap()` để vẽ
# - Thêm annotations (giá trị) trên mỗi ô
# - Tùy chỉnh colormap phù hợp

# %%
# 📊 BÀI TẬP 5.1: Heatmap (Bản đồ nhiệt)
# Hãy hoàn thành các yêu cầu dưới đây:
# Lưu ý: Sử dụng dữ liệu đã tạo sẵn (customer_data) từ cell "Tạo dữ liệu ban đầu"

import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# 1. Sử dụng dữ liệu đã tạo sẵn
print("📊 Sử dụng dữ liệu khách hàng...")
print(f"Số lượng khách hàng: {len(customer_data)}")
print(customer_data.head())

# 2. Tính ma trận tương quan
print("\n📊 Tính ma trận tương quan...")

# TODO: Chọn các cột số từ customer_data (Tuoi, ThuNhap, ChiTieu)
# TODO: Tính ma trận tương quan

# 3. Vẽ heatmap
print("\n🔥 Vẽ heatmap...")

# TODO: Tạo figure
# TODO: Sử dụng sns.heatmap() để vẽ ma trận tương quan với annotations
# TODO: Thêm tiêu đề
# TODO: Hiển thị biểu đồ
# TODO: In nhận xét về mối tương quan

print("\n✅ Hoàn thành Bài tập 5.1!")
# Out:
# 📊 Sử dụng dữ liệu khách hàng...
# Số lượng khách hàng: 150
#    Tuoi   ThuNhap   ChiTieu GioiTinh ThanhPho
# 0    44  11000000  12000000       Nữ   Hà Nội
# 1    48  44000000   6000000      Nam  Đà Nẵng
# 2    23  43000000  28000000      Nam  Cần Thơ
# 3    44  39000000  17000000       Nữ   Hà Nội
# 4    57  22000000   7000000      Nam  Cần Thơ
#
# 📊 Tính ma trận tương quan...
#
# 🔥 Vẽ heatmap...
#
# ✅ Hoàn thành Bài tập 5.1!

# %% [markdown]
# ## Bài 5.2 - Violin Plot
#
# ### 📊 Tình huống thực tế
# Bạn cần so sánh phân bố chi tiêu của khách hàng theo giới tính. Violin plot kết hợp boxplot và density plot, cho phép bạn thấy cả thống kê tóm tắt và hình dạng phân bố chi tiết.
#
# ### 🎯 Nhiệm vụ của bạn:
# 1. **Sử dụng dữ liệu khách hàng** đã tạo sẵn
# 2. **Vẽ violin plot** so sánh chi tiêu theo giới tính
# 3. **So sánh với boxplot** để thấy sự khác biệt
#
# ### 📋 Yêu cầu cụ thể:
# - Sử dụng `sns.violinplot()` để vẽ
# - So sánh ChiTieu theo GioiTinh
# - Tùy chỉnh màu sắc và style

# %%
# 📊 BÀI TẬP 5.2: Violin Plot
# Hãy hoàn thành các yêu cầu dưới đây:
# Lưu ý: Sử dụng dữ liệu đã tạo sẵn (customer_data) từ cell "Tạo dữ liệu ban đầu"

import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# 1. Sử dụng dữ liệu đã tạo sẵn
print("📊 Sử dụng dữ liệu khách hàng...")
print(f"Phân bố theo giới tính:\n{customer_data['GioiTinh'].value_counts()}")

# 2. Vẽ violin plot
print("\n🎻 Vẽ violin plot...")

# TODO: Tạo figure với 2 subplot (violin plot và boxplot để so sánh)
# TODO: Vẽ violin plot trên subplot đầu tiên với sns.violinplot()
# TODO: Vẽ boxplot trên subplot thứ hai để so sánh
# TODO: Thêm tiêu đề và nhãn cho cả hai subplot
# TODO: Hiển thị biểu đồ
# TODO: In thống kê so sánh chi tiêu theo giới tính

print("\n✅ Hoàn thành Bài tập 5.2!")
# Out:
# 📊 Sử dụng dữ liệu khách hàng...
# Phân bố theo giới tính:
# GioiTinh
# Nữ     83
# Nam    67
# Name: count, dtype: int64
#
# 🎻 Vẽ violin plot...
#
# ✅ Hoàn thành Bài tập 5.2!

# %% [markdown]
# ## Bài 5.3 - Pair Plot (Biểu đồ cặp)
#
# ### 📊 Tình huống thực tế
# Bạn muốn khám phá mối quan hệ giữa tất cả các biến số trong dữ liệu khách hàng cùng một lúc. Pair plot cho phép bạn xem tất cả các scatter plot và histogram trong một biểu đồ duy nhất.
#
# ### 🎯 Nhiệm vụ của bạn:
# 1. **Sử dụng dữ liệu khách hàng** đã tạo sẵn
# 2. **Vẽ pair plot** với seaborn
# 3. **Thêm phân loại theo giới tính** để so sánh
#
# ### 📋 Yêu cầu cụ thể:
# - Sử dụng `sns.pairplot()` trên các cột số
# - Thêm `hue='GioiTinh'` để phân loại theo màu
# - Tùy chỉnh diag_kind và plot_kws

# %%
# 📊 BÀI TẬP 5.3: Pair Plot (Biểu đồ cặp)
# Hãy hoàn thành các yêu cầu dưới đây:
# Lưu ý: Sử dụng dữ liệu đã tạo sẵn (customer_data) từ cell "Tạo dữ liệu ban đầu"

import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# 1. Sử dụng dữ liệu đã tạo sẵn
print("📊 Sử dụng dữ liệu khách hàng...")
print(f"Các cột số: Tuoi, ThuNhap, ChiTieu")
print(f"Cột phân loại: GioiTinh")

# 2. Vẽ pair plot
print("\n🔗 Vẽ pair plot...")

# TODO: Chọn các cột cần thiết cho pair plot
# TODO: Sử dụng sns.pairplot() với hue='GioiTinh' để phân loại theo màu
# TODO: Thêm tiêu đề tổng thể
# TODO: Hiển thị biểu đồ

print("\n💡 Lưu ý: Pair plot hiển thị tất cả các mối quan hệ giữa các biến số.")
print("Đường chéo: phân bố của từng biến (histogram hoặc KDE)")
print("Ngoài đường chéo: scatter plot giữa các cặp biến")

print("\n✅ Hoàn thành Bài tập 5.3!")
# Out:
# 📊 Sử dụng dữ liệu khách hàng...
# Các cột số: Tuoi, ThuNhap, ChiTieu
# Cột phân loại: GioiTinh
#
# 🔗 Vẽ pair plot...
#
# 💡 Lưu ý: Pair plot hiển thị tất cả các mối quan hệ giữa các biến số.
# Đường chéo: phân bố của từng biến (histogram hoặc KDE)
# Ngoài đường chéo: scatter plot giữa các cặp biến
#
# ✅ Hoàn thành Bài tập 5.3!

# %% [markdown]
# # 📊 Phần 6: Trực quan hóa nâng cao
#
# ## Bài 6.1 - Subplots với nhiều biểu đồ
#
# ### 📊 Tình huống thực tế
# Bạn cần tạo một dashboard với nhiều biểu đồ khác nhau để trình bày tổng quan về hiệu suất bán hàng của nhân viên. Subplots cho phép bạn hiển thị nhiều biểu đồ trong một figure.
#
# ### 🎯 Nhiệm vụ của bạn:
# 1. **Sử dụng dữ liệu bán hàng nhân viên** đã tạo sẵn
# 2. **Tạo subplot 2x2** với 4 biểu đồ khác nhau
# 3. **Mỗi subplot** hiển thị một khía cạnh khác nhau của dữ liệu
#
# ### 📋 Yêu cầu cụ thể:
# - Subplot 1: Line plot so sánh doanh số 4 nhân viên theo tháng
# - Subplot 2: Bar chart tổng doanh số của mỗi nhân viên
# - Subplot 3: Area chart (stacked) tổng hợp
# - Subplot 4: Boxplot so sánh phân bố doanh số

# %%
# 📊 BÀI TẬP 6.1: Subplots với nhiều biểu đồ
# Hãy hoàn thành các yêu cầu dưới đây:
# Lưu ý: Sử dụng dữ liệu đã tạo sẵn (sales_employees) từ cell "Tạo dữ liệu ban đầu"

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# 1. Sử dụng dữ liệu đã tạo sẵn
print("📊 Sử dụng dữ liệu bán hàng nhân viên...")
print(sales_employees.head())

# 2. Tạo subplots
print("\n📊 Tạo dashboard với subplots...")

# TODO: Tạo figure với 2x2 subplots và thêm tiêu đề tổng thể
# TODO: Subplot 1 (0,0): Line plot so sánh doanh số 4 nhân viên theo tháng
# TODO: Subplot 2 (0,1): Bar chart tổng doanh số của mỗi nhân viên
# TODO: Subplot 3 (1,0): Area chart (stacked) tổng hợp
# TODO: Subplot 4 (1,1): Boxplot so sánh phân bố doanh số
# TODO: Hiển thị biểu đồ

print("\n✅ Hoàn thành Bài tập 6.1!")
# Out:
# 📊 Sử dụng dữ liệu bán hàng nhân viên...
#        Thang  NV_A  NV_B  NV_C  NV_D
# 0 2024-01-31    75    70    85    92
# 1 2024-02-29    78    65    82    66
# 2 2024-03-31    94    77    78    77
# 3 2024-04-30    83    80    61    96
# 4 2024-05-31    72   101    81    76
#
# 📊 Tạo dashboard với subplots...
#
# ✅ Hoàn thành Bài tập 6.1!

# %%
# 📊 BÀI TẬP 6.2: Biểu đồ theo nhóm (Grouped Visualization)
# Hãy hoàn thành các yêu cầu dưới đây:
# Lưu ý: Sử dụng dữ liệu đã tạo sẵn (customer_data) từ cell "Tạo dữ liệu ban đầu"

import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# 1. Sử dụng dữ liệu đã tạo sẵn
print("📊 Sử dụng dữ liệu khách hàng...")
print(f"Phân bố theo thành phố:\n{customer_data['ThanhPho'].value_counts()}")

# 2. Vẽ biểu đồ theo nhóm
print("\n📊 Vẽ biểu đồ theo nhóm...")

# TODO: Tạo figure với 2 subplot
# TODO: Subplot 1: Bar chart thu nhập trung bình theo thành phố với sns.barplot()
# TODO: Subplot 2: Bar chart chi tiêu trung bình theo thành phố và giới tính
# TODO: Thêm tiêu đề và nhãn cho cả hai subplot
# TODO: Hiển thị biểu đồ
# TODO: In thống kê theo nhóm (groupby)

print("\n✅ Hoàn thành Bài tập 6.2!")
# Out:
# 📊 Sử dụng dữ liệu khách hàng...
# Phân bố theo thành phố:
# ThanhPho
# Hà Nội     43
# TP.HCM     38
# Cần Thơ    37
# Đà Nẵng    32
# Name: count, dtype: int64
#
# 📊 Vẽ biểu đồ theo nhóm...
#
# ✅ Hoàn thành Bài tập 6.2!

# %% [markdown]
# ## Bài 6.3 - Time Series Visualization
#
# ### 📊 Tình huống thực tế
# Bạn cần phân tích xu hướng doanh thu theo thời gian và so sánh giữa các sản phẩm. Time series visualization giúp bạn nhận thấy các mẫu theo thời gian.
#
# ### 🎯 Nhiệm vụ của bạn:
# 1. **Sử dụng dữ liệu doanh thu** đã tạo sẵn
# 2. **Vẽ biểu đồ chuỗi thời gian** với nhiều cách khác nhau
# 3. **Phân tích xu hướng** và mùa vụ
#
# ### 📋 Yêu cầu cụ thể:
# - Vẽ line plot với pandas cho tất cả sản phẩm
# - Vẽ area chart để thấy tổng doanh thu
# - Thêm moving average (trung bình động) để làm mượt xu hướng

# %%
# 📊 BÀI TẬP 6.3: Time Series Visualization
# Hãy hoàn thành các yêu cầu dưới đây:
# Lưu ý: Sử dụng dữ liệu đã tạo sẵn (df_revenue) từ cell "Tạo dữ liệu ban đầu"

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# 1. Sử dụng dữ liệu đã tạo sẵn
print("📊 Sử dụng dữ liệu doanh thu theo thời gian...")
print(df_revenue.head())

# 2. Vẽ biểu đồ chuỗi thời gian
print("\n📈 Vẽ biểu đồ chuỗi thời gian...")

# TODO: Tạo figure với 2 subplot
# TODO: Subplot 1: Line plot với moving average (trung bình động 3 tháng)
# TODO: Subplot 2: Area chart tổng doanh thu
# TODO: Thêm tiêu đề và nhãn cho cả hai subplot
# TODO: Hiển thị biểu đồ
# TODO: Tính và in thống kê xu hướng (tăng trưởng %)

print("\n✅ Hoàn thành Bài tập 6.3!")
# Out:
# 📊 Sử dụng dữ liệu doanh thu theo thời gian...
#             SanPham_A  SanPham_B  SanPham_C
# 2024-01-31        146        173        206
# 2024-02-29        314        261        421
# 2024-03-31        433        438        621
# 2024-04-30        543        570        821
# 2024-05-31        644        693        954
#
# 📈 Vẽ biểu đồ chuỗi thời gian...
#
# ✅ Hoàn thành Bài tập 6.3!

# %% [markdown]
# ## Bài 6.4 - Customization và Styling nâng cao
#
# ### 📊 Tình huống thực tế
# Bạn cần tạo một biểu đồ chuyên nghiệp để trình bày trong báo cáo. Việc tùy chỉnh màu sắc, font chữ, và layout là rất quan trọng.
#
# ### 🎯 Nhiệm vụ của bạn:
# 1. **Tạo một biểu đồ tổng hợp** với nhiều yếu tố
# 2. **Tùy chỉnh toàn bộ** style và appearance
# 3. **Thêm annotations** và highlights
#
# ### 📋 Yêu cầu cụ thể:
# - Vẽ biểu đồ kết hợp line và bar chart
# - Tùy chỉnh màu sắc, font, và layout
# - Thêm annotations cho các điểm quan trọng
# - Tạo một biểu đồ đẹp và chuyên nghiệp

# %%
# 📊 BÀI TẬP 6.4: Customization và Styling nâng cao
# Hãy hoàn thành các yêu cầu dưới đây:
# Lưu ý: Sử dụng dữ liệu đã tạo sẵn (df_revenue) từ cell "Tạo dữ liệu ban đầu"

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# 1. Sử dụng dữ liệu đã tạo sẵn
print("📊 Tạo biểu đồ chuyên nghiệp...")

# 2. Tạo biểu đồ với customization nâng cao
print("\n🎨 Vẽ biểu đồ với styling nâng cao...")

# TODO: Tạo figure với style chuyên nghiệp
# TODO: Vẽ line plot cho từng sản phẩm với màu sắc và style khác nhau
# TODO: Tìm và highlight tháng có doanh thu cao nhất (sử dụng scatter và annotate)
# TODO: Tùy chỉnh tiêu đề, nhãn, legend, grid, và ticks
# TODO: Thêm text box với thông tin tổng quan
# TODO: Hiển thị biểu đồ

print("\n✅ Hoàn thành Bài tập 6.4!")
print("\n🎉 Chúc mừng! Bạn đã hoàn thành tất cả bài tập!")
print("📚 Hãy xem lại các nguyên tắc thiết kế trong Lecture 7 để áp dụng vào thực tế!")
# Out:
# 📊 Tạo biểu đồ chuyên nghiệp...
#
# 🎨 Vẽ biểu đồ với styling nâng cao...
#
# ✅ Hoàn thành Bài tập 6.4!
#
# 🎉 Chúc mừng! Bạn đã hoàn thành tất cả bài tập!
# 📚 Hãy xem lại các nguyên tắc thiết kế trong Lecture 7 để áp dụng vào thực tế!
